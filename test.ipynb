# %%
from ml.distributions import StudentsτDistribution
from scipy.stats import t
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5,5,100)
std = StudentsτDistribution(0,1,1)
plt.plot(x, std.cdf(x))
plt.plot(x, t.cdf(x, 1))

# %%
from ml.regression import LinearRegression
import matplotlib.pyplot as plt

linreg = LinearRegression(1,1)
data = linreg.sample(100,0,5,0.5,3,0,0.5)

plt.scatter(data[:,0], data[:,1])
plt.plot(data[:,0], linreg.linear_function(data,None,None))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       5 data = linreg.sample(100,0,5,0.5,3,0,0.5)
#       7 plt.scatter(data[:,0], data[:,1])
# ----> 8 plt.plot(data[:,0], linreg.linear_function(data,None,None))
#
# File d:\BME\machine-learning\ml\regression\linreg.py:37, in LinearRegression.linear_function(self, x, m, b)
#      35 if m != None:
#      36     self.m = m
# ---> 37 if b != None:
#      38     self.b = b
#      39 return self.m * x + self.b
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'float'
